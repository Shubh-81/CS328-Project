# %%
import pandas as pd

# %%
df = pd.read_csv('results.csv')

# %%
df
# Out:
#                     Sampling Type  Coreset Size  Average Cost  \
# 0             Norm Based Sampling           500  5.708303e+10
# 1             Norm Based Sampling          1000  4.463988e+10
# 2             Norm Based Sampling          2000  3.479039e+10
# 3             Norm Based Sampling          5000  2.685408e+10
# 4             Norm Based Sampling          7000  2.748591e+10
# 5             Norm Based Sampling         10000  2.040315e+10
# 6                Uniform Sampling           500  5.215751e+10
# 7                Uniform Sampling          1000  4.560504e+10
# 8                Uniform Sampling          2000  3.890950e+10
# 9                Uniform Sampling          5000  2.703307e+10
# 10               Uniform Sampling          7000  2.114760e+10
# 11               Uniform Sampling         10000  2.040188e+10
# 12  Statistical Leverage Sampling           500  5.315079e+10
# 13  Statistical Leverage Sampling          1000  4.281110e+10
# ...

# %%
df['Clustering Algorithm'] = 'KMeans++'

# %%
df.to_csv('results.csv', index=False)
